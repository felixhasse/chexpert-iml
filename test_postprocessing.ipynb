# %% [markdown]
# ### Import necessary modules

# %%
import torch
from torchvision import transforms
from postprocessing import *
from PIL import Image
import matplotlib.pyplot as plt

# %% [markdown]
# ### Test extraction of largest connected components

# %%
mask = Image.open("data/chexpert_masks/masks/lung/patient00004/study1/view1_frontal.png").convert("1")
mask = transforms.ToTensor()(mask)
processed_mask = largest_connected_components(mask, 3)
mask = transforms.ToPILImage()(mask)
processed_mask = transforms.ToPILImage()(processed_mask)
fig, (ax1, ax2) = plt.subplots(1, 2)
ax1.imshow(mask)
ax2.imshow(processed_mask)
